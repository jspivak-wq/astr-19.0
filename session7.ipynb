# %%
import matplotlib.pyplot as plt
import numpy as np
import math
n = 100
x = np.linspace(0, 1, n)
def exp(x):
    return np.exp(x)

# %%
y = np.exp(x)

# %%
plt.plot(x, y)
plt.xlabel ('Time[miliseconds')
plt.ylabel('awesomeness')

plt.savefig('expx.pdf', bbox_inches = 'tight', dpi = 600)

plt.show()
